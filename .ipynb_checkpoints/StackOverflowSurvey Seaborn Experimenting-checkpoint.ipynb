# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

sos = pd.read_csv('D:\LearnSeaborn\StackOverflowServeyData\survey_results_public.csv')

sos.rename(columns = {'ConvertedComp':'Salary'}, inplace = True)

# %%
#gets top countries in order of avg salary
sos.loc[sos['Salary'] > 1000].groupby('Country').mean().sort_values('Salary', ascending = False).head(10)
# Out:
#                                     Respondent        Age      CompTotal  \
# Country
# Nomadic                           26450.142857  33.083333   7.142857e+54
# Lao People's Democratic Republic  51570.000000  45.000000   2.019003e+08
# United States                     28317.906285  34.390115  1.371911e+243
# Ireland                           28306.059649  32.519149   6.512505e+04
# Afghanistan                       37940.761905  24.000000   6.796095e+08
# Australia                         30121.256510  34.660322   1.251677e+05
# Norway                            30631.607407  34.674897   6.723460e+05
# Switzerland                       28784.642659  32.400602   8.521395e+04
# United Kingdom                    29958.392621  33.344574   3.883582e+09
# New Zealand                       30280.554455  34.153846   1.008587e+05
#
#                                          Salary  WorkWeekHrs
# Country
# Nomadic                           310924.142857    41.857143
# Lao People's Democratic Republic  231275.250000    43.000000
# United States                     210192.503642    41.748519
# Ireland                           183000.740351    39.657609
# Afghanistan                       169432.095238    43.800000
# Australia                         146926.833333    39.979597
# Norway                            143899.074074    55.870229
# Switzerland                       142001.936288    39.391168
# United Kingdom                    141559.972816    39.151131
# New Zealand                       141540.301980    40.264179

# %%
clean_sos = sos.loc[(sos['CompFreq'] == 'Yearly')&(sos['Salary'] > 10000)&(sos['Salary'] < 400000)]

# %%
agreg_sos = clean_sos.groupby('Age').mean().reset_index()
agreg_sos = agreg_sos.loc[(agreg_sos['Age'] >= 18)&(agreg_sos['Age'] <= 90)]
agreg_sos
#sns.lineplot(x='Age', y='Salary', data = agreg_sos)
sns.relplot(x='Age', y='Salary', data = agreg_sos, kind = 'line')
#either one

#plt.xticks([], rotation = 70)

# %%
usa = clean_sos.loc[clean_sos['Country'] == "United States"]
usa
# Out:
#        Respondent                                         MainBranch Hobbyist  \
# 7               8                     I am a developer by profession      Yes
# 13             14                     I am a developer by profession      Yes
# 16             17                     I am a developer by profession      Yes
# 18             19                     I am a developer by profession       No
# 40             41                     I am a developer by profession       No
# ...           ...                                                ...      ...
# 64083       65554                     I am a developer by profession      Yes
# 64113       65586                     I am a developer by profession      Yes
# 64116       65589                     I am a developer by profession      Yes
# 64122       65596                     I am a developer by profession      Yes
# 64127       65602  I am not primarily a developer, but I write co...      Yes
#
#         Age Age1stCode CompFreq  CompTotal    Salary        Country  \
# 7      36.0         12   Yearly   116000.0  116000.0  United States
# 13     27.0         13   Yearly    66000.0   66000.0  United States
# 16     25.0         14   Yearly    79000.0   79000.0  United States
# 18     24.0         15   Yearly    83400.0   83400.0  United States
# 40      NaN         15   Yearly   106000.0  106000.0  United States
# ...     ...        ...      ...        ...       ...            ...
# 64083   NaN         13   Yearly   230000.0  230000.0  United States
# 64113   NaN          8   Yearly   225000.0  225000.0  United States
# 64116   NaN         16   Yearly   150000.0  150000.0  United States
# 64122   NaN         22   Yearly    70000.0   70000.0  United States
# 64127   NaN         13   Yearly   140000.0  140000.0  United States
#
#                CurrencyDesc  ...                  SurveyEase  \
# 7      United States dollar  ...                        Easy
# 13     United States dollar  ...  Neither easy nor difficult
# 16     United States dollar  ...                        Easy
# 18     United States dollar  ...                        Easy
# 40     United States dollar  ...                         NaN
# ...                     ...  ...                         ...
# 64083  United States dollar  ...                         NaN
# 64113  United States dollar  ...                         NaN
# 64116  United States dollar  ...                         NaN
# 64122  United States dollar  ...                         NaN
# 64127  United States dollar  ...                         NaN
#
#                 SurveyLength Trans  \
# 7      Appropriate in length    No
# 13     Appropriate in length    No
# 16     Appropriate in length    No
# 18     Appropriate in length    No
# 40                       NaN   NaN
# ...                      ...   ...
# 64083                    NaN   NaN
# 64113                    NaN   NaN
# 64116                    NaN   NaN
# 64122                    NaN   NaN
# 64127                    NaN   NaN
#
#                                           UndergradMajor  \
# 7      Computer science, computer engineering, or sof...
# 13     Computer science, computer engineering, or sof...
# 16     Computer science, computer engineering, or sof...
# 18     Computer science, computer engineering, or sof...
# 40     Computer science, computer engineering, or sof...
# ...                                                  ...
# 64083  Computer science, computer engineering, or sof...
# 64113                          Mathematics or statistics
# 64116  Computer science, computer engineering, or sof...
# 64122                      Web development or web design
# 64127  Another engineering discipline (such as civil,...
#
#                     WebframeDesireNextYear  \
# 7                   Django;React.js;Vue.js
# 13                          Angular;Vue.js
# 16     ASP.NET Core;Gatsby;React.js;Vue.js
# 18                 Django;Express;React.js
# 40                                  Vue.js
# ...                                    ...
# 64083                                  NaN
# 64113                                  NaN
# 64116                                  NaN
# 64122                                  NaN
# 64127                                  NaN
#
#                                     WebframeWorkedWith  \
# 7                                                Flask
# 13                                      Angular;Vue.js
# 16               ASP.NET;Gatsby;jQuery;React.js;Vue.js
# 18                     Angular;Angular.js;ASP.NET Core
# 40                                      ASP.NET;Vue.js
# ...                                                ...
# 64083                                              NaN
# 64113                                              NaN
# 64116                                              NaN
# 64122  Angular.js;Django;jQuery;React.js;Ruby on Rails
# 64127                                              NaN
#
#                                  WelcomeChange WorkWeekHrs YearsCode  \
# 7      Just as welcome now as I felt last year        39.0        17
# 13     Just as welcome now as I felt last year        40.0         5
# 16     Just as welcome now as I felt last year        40.0         7
# 18     Just as welcome now as I felt last year        35.0         9
# 40       A lot less welcome now than last year        40.0        25
# ...                                        ...         ...       ...
# 64083                                      NaN        40.0        17
# 64113                                      NaN        50.0        25
# 64116                                      NaN        45.0        10
# 64122    A lot more welcome now than last year        40.0         6
# 64127                                      NaN         NaN        15
#
#       YearsCodePro
# 7               13
# 13               1
# 16               3
# 18               3
# 40              20
# ...            ...
# 64083            7
# 64113           15
# 64116            6
# 64122            4
# 64127           12
#
# [7194 rows x 61 columns]

# %%
#shows scatterplot of salaries with hue being whether their a professional dev or they just dev in the their work
#As u can see the people who were developers bvy profession had higher salaries on avg than those who just coded as part of their work
sns.relplot('Salary', 'Age', data=usa, kind = 'line', hue = 'MainBranch')

# %%
sns.relplot('Salary', 'Age', data=usa, kind = 'line', col = 'Hobbyist', hue = 'MainBranch')

# %%
#cat plot
sns.catplot('MainBranch', 'Salary', data=clean_sos)

# %%
#swarm plot
sns.catplot('MainBranch', 'Salary', data=clean_sos, kind = 'swarm')

# %%
#box plot to get rid of outliers
sns.catplot('MainBranch', 'Salary', data=sos, kind = 'box')
